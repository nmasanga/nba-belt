# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup, SoupStrainer
import sys
import string
import requests
import datetime
from datetime import timedelta
import time

# %%
## backfill
first_game = datetime.datetime.strptime('2019-10-22', "%Y-%m-%d")
last_game = datetime.datetime.strptime('2020-04-15', "%Y-%m-%d")
winning_team = 'Toronto'
pd.options.display.max_colwidth = 100
game_date = first_game

columns = ['date','Winner', 'Winner_Score', 'Loser', 'Loser_Score', 'box_score']
df = pd.DataFrame(columns = columns)

while game_date < datetime.datetime.now() and datetime.datetime.now() <= last_game:
    d = game_date.day
    m = game_date.month
    y = game_date.year
    date_str = str(y) + '-' + str(m) + '-' + str(d)
    
    base_url = 'http://basketball-reference.com/boxscores/index.fcgi?month=' + str(m) + '&day=' +str(d)+'&year=' + str(y)
    page_response = requests.get(base_url, timeout=5)
    page_content = BeautifulSoup(page_response.content, "html.parser")
    
    scores = page_content.find_all('table', {'class': 'teams'})
    
    for games in scores:
        if winning_team in str(games):
            data = []
            champ_score = games

            winner = champ_score.find('tr', {'class':'winner'}) ## find row that has the winner
            winning_team = winner.find('a').string ## winning team name
            winning_score = winner.find('td', {'class':'right'}).string ## winning team score

            loser = champ_score.find('tr', {'class':'loser'}) ## find row that has the loser
            losing_team = loser.find('a').string ## losing team name
            losing_score = loser.find('td', {'class':'right'}).string ## losing team score

            box_score_td = champ_score.find('td', {'class':['gamelink']}) ## find the box score link
            href = box_score_td.find('a')['href'] ## get the href from the anchor tag
            box_score_url = 'https://www.basketball-reference.com' + href
            # anchor_tag = href='https://www.basketball-reference.com" + href + "'>" + 'Link</a>'


            data.insert(0, {'date': date_str,
                            'Winner': winning_team,
                            'Winner_Score': winning_score,
                            'Loser': losing_team,
                            'Loser_Score': losing_score,
                            'box_score': box_score_url})
            df = pd.concat([pd.DataFrame(data), df], ignore_index=True)
            break
        else:
            continue

    game_date = game_date + timedelta(days=1)

columns = ['date','Winner', 'Winner_Score', 'Loser', 'Loser_Score', 'box_score']
df = df[columns] # reorder columns
# df = df.set_index('date') # set index to date

# %%
df.head()
# Out:
#         date   Winner Winner_Score     Loser Loser_Score  \
# 0  2020-3-10   Boston          114   Indiana         111
# 1   2020-3-8  Indiana          112    Dallas         109
# 2   2020-3-6   Dallas          121   Memphis          96
# 3   2020-3-4  Memphis          118  Brooklyn          79
# 4   2020-3-2  Memphis          127   Atlanta          88
#
#                                                           box_score
# 0  https://www.basketball-reference.com/boxscores/202003100IND.html
# 1  https://www.basketball-reference.com/boxscores/202003080DAL.html
# 2  https://www.basketball-reference.com/boxscores/202003060DAL.html
# 3  https://www.basketball-reference.com/boxscores/202003040BRK.html
# 4  https://www.basketball-reference.com/boxscores/202003020ATL.html

# %%
## find winner
belt_holder = df['Winner'][0]
print("Current championship belt holder: " + belt_holder)
# Out:
# Current championship belt holder: Boston

# %%
## find team with the most title defenses
winner_count = df.groupby('Winner').count()[['Winner_Score']] ## get count of each games won while holding belt
winner_count = winner_count.sort_values('Winner_Score', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last') ## reorder
winner_count = winner_count.reset_index(drop=False) ## remove index so Winner header can be called
most_win_team = winner_count['Winner'][0]
most_wins = winner_count['Winner_Score'][0]

print("The team with the most title defenses: " + most_win_team)
print("They have " + str(most_wins) + " title defense wins.")
# Out:
# The team with the most title defenses: Boston
# They have 15 title defense wins.

# %%
winner_count.head()
# Out:
#       Winner  Winner_Score
# 0     Boston            15
# 1    Memphis            10
# 2    Indiana             6
# 3  LA Lakers             5
# 4  Milwaukee             5

# %%
new_df = df
new_df.head()
# Out:
#         date   Winner Winner_Score     Loser Loser_Score  \
# 0  2020-3-10   Boston          114   Indiana         111
# 1   2020-3-8  Indiana          112    Dallas         109
# 2   2020-3-6   Dallas          121   Memphis          96
# 3   2020-3-4  Memphis          118  Brooklyn          79
# 4   2020-3-2  Memphis          127   Atlanta          88
#
#                                                           box_score
# 0  https://www.basketball-reference.com/boxscores/202003100IND.html
# 1  https://www.basketball-reference.com/boxscores/202003080DAL.html
# 2  https://www.basketball-reference.com/boxscores/202003060DAL.html
# 3  https://www.basketball-reference.com/boxscores/202003040BRK.html
# 4  https://www.basketball-reference.com/boxscores/202003020ATL.html

# %%
new_df = new_df.set_index('date') # set index to date

# %%
new_df = new_df.reset_index(drop=False)

# %%
new_df = new_df.reset_index(drop=True, inplace=True)

# %%
new_df

# %%
new_df.size()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-b6ebfcbc4a76> in <module>()
# ----> 1 new_df.size()
#
# AttributeError: 'NoneType' object has no attribute 'size'

# %%
df2 = new_df.reset_index()

# %%
df2
# Out:
#     index        date        Winner Winner_Score         Loser Loser_Score  \
# 0       0   2020-3-10        Boston          114       Indiana         111
# 1       1    2020-3-8       Indiana          112        Dallas         109
# 2       2    2020-3-6        Dallas          121       Memphis          96
# 3       3    2020-3-4       Memphis          118      Brooklyn          79
# 4       4    2020-3-2       Memphis          127       Atlanta          88
# 5       5   2020-2-29       Memphis          105     LA Lakers          88
# 6       6   2020-2-27     LA Lakers          116  Golden State          86
# 7       7   2020-2-25     LA Lakers          118   New Orleans         109
# 8       8   2020-2-23     LA Lakers          114        Boston         112
# 9       9   2020-2-21     LA Lakers          117       Memphis         105
# 10     10   2020-2-12     LA Lakers          120        Denver         116
# 11     11   2020-2-10        Denver          127   San Antonio         120
# 12     12    2020-2-8        Denver          117       Phoenix         108
# 13     13    2020-2-7       Phoenix          127       Houston          91
# 14     14    2020-2-6       Houston          121     LA Lakers         111
# 15     15    2020-2-4       Houston          125     Charlotte         110
# 16     16    2020-2-2       Houston          117   New Orleans         109
# 17     17   2020-1-31   New Orleans          139       Memphis         111
# 18     18   2020-1-29       Memphis          127      New York         106
# 19     19   2020-1-28       Memphis          104        Denver          96
# 20     20   2020-1-26       Memphis          114       Phoenix         109
# 21     21   2020-1-24       Phoenix          103   San Antonio          99
# 22     22   2020-1-22   San Antonio          121   New Orleans         117
# 23     23   2020-1-20   New Orleans          126       Memphis         116
# 24     24   2020-1-17       Memphis          113     Cleveland         109
# 25     25   2020-1-14       Memphis          121       Houston         110
# 26     26   2020-1-12       Memphis          122  Golden State         102
# 27     27   2020-1-10       Memphis          134   San Antonio         121
# 28     28    2020-1-8   San Antonio          129        Boston         114
# 29     29    2020-1-6   San Antonio          126     Milwaukee         104
# ..    ...         ...           ...          ...           ...         ...
# 35     35  2019-12-25  Philadelphia          121     Milwaukee         109
# 36     36  2019-12-22     Milwaukee          117       Indiana          89
# 37     37  2019-12-20       Indiana          119    Sacramento         105
# 38     38  2019-12-17       Indiana          105     LA Lakers         102
# 39     39  2019-12-15       Indiana          107     Charlotte          85
# 40     40  2019-12-13       Indiana          110       Atlanta         100
# 41     41  2019-12-11       Indiana          122        Boston         117
# 42     42   2019-12-9        Boston          110     Cleveland          88
# 43     43   2019-12-6        Boston          108        Denver          95
# 44     44   2019-12-4        Boston          112         Miami          93
# 45     45   2019-12-3         Miami          121       Toronto         110
# 46     46   2019-12-1         Miami          109      Brooklyn         106
# 47     47  2019-11-29      Brooklyn          112        Boston         107
# 48     48  2019-11-27        Boston          121      Brooklyn         110
# 49     49  2019-11-25      Brooklyn          108     Cleveland         106
# 50     50  2019-11-24      Brooklyn          103      New York         101
# 51     51  2019-11-22      Brooklyn          116    Sacramento          97
# 52     52  2019-11-19    Sacramento          120       Phoenix         116
# 53     53  2019-11-17    Sacramento          100        Boston          99
# 54     54  2019-11-15        Boston          105  Golden State         100
# 55     55  2019-11-13        Boston          140    Washington         133
# 56     56  2019-11-11        Boston          116        Dallas         106
# 57     57   2019-11-9        Boston          135   San Antonio         115
# 58     58   2019-11-7        Boston          108     Charlotte          87
# 59     59   2019-11-5        Boston          119     Cleveland         113
# 60     60   2019-11-1        Boston          104      New York         102
# 61     61  2019-10-30        Boston          116     Milwaukee         105
# 62     62  2019-10-26        Boston          118      New York          95
# 63     63  2019-10-25        Boston          112       Toronto         106
# 64     64  2019-10-22       Toronto          130   New Orleans         122
#
#                                                            box_score
# 0   https://www.basketball-reference.com/boxscores/202003100IND.html
# 1   https://www.basketball-reference.com/boxscores/202003080DAL.html
# 2   https://www.basketball-reference.com/boxscores/202003060DAL.html
# 3   https://www.basketball-reference.com/boxscores/202003040BRK.html
# 4   https://www.basketball-reference.com/boxscores/202003020ATL.html
# 5   https://www.basketball-reference.com/boxscores/202002290MEM.html
# 6   https://www.basketball-reference.com/boxscores/202002270GSW.html
# 7   https://www.basketball-reference.com/boxscores/202002250LAL.html
# 8   https://www.basketball-reference.com/boxscores/202002230LAL.html
# 9   https://www.basketball-reference.com/boxscores/202002210LAL.html
# 10  https://www.basketball-reference.com/boxscores/202002120DEN.html
# 11  https://www.basketball-reference.com/boxscores/202002100DEN.html
# 12  https://www.basketball-reference.com/boxscores/202002080PHO.html
# 13  https://www.basketball-reference.com/boxscores/202002070PHO.html
